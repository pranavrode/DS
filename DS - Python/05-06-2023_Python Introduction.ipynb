# %% [markdown]
# # Jupyter Notebook File

# %%
a = 5
b = 6

a+b
# Out:
# 11

# %% [markdown]
# # To run Python code or cell:

# %%
1. control + Enter >> Used to execute current cell only

# %%
a = 6
b = 7

a*b
# Out:
# 42

# %%
2. shift + Enter >> Used to run current cell and Select next or below cell

# %%
a = 6
b = 7

a*b
# Out:
# 42

# %%
3. Alt + Enter >> Used to run current cell and add new blank cell

# %%
a = 6
b = 7

a+b
# Out:
# 13

# %% [markdown]
# # Heading

# %% [markdown]
# #### Heading

# %%
To add image >> copy image >> select cell >> convert it into markdowm >> paste image in cell>> run the cell

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %%
Convert mardown to code cell  >> esc + y
convert markdown to raw       >> esc + r
To display the image          >> esc + m

# %%
a = 4
b = 5

print(a+b)
# Out:
# 9

# %%
print("I am learning Python")
# Out:
# I am learning Python

# %%
Algorithm >> set of instructions that works on some given data in a particular way

# %% [markdown]
# # Python

# %%
# Addition program in python-

a = 5 
b = 6

print("Addition of a and b is",a+b)
# Out:
# Addition of a and b is 11

# %%
#Addition program in C language:

#include <stdio.h>
int main() {    

    int number1, number2, sum;
    
    printf("Enter two integers: ");
    scanf("%d %d", &number1, &number2);

    // calculate the sum
    sum = number1 + number2;      
    
    printf("%d + %d = %d", number1, number2, sum);
    return 0;
}

# %% [markdown]
# # Python Features

# %%
Guido Van Rossam >> 1991

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Features of Python:

# %%
1. Easy to Code : Python is a very high-level programming language
    Python syntax is very easy, as compared to other popular languages like C, C++, and Java. 


2. Easy to Read : 
    There is no use of semicolons or brackets, and the indentations define the code block.
    
3. Free and Open-Source:
    completely free to use, even for commercial purposes
    
4. Robust Standard Library:
    Python has an extensive standard library available for anyone to use
    
    This means that programmers don’t have to write their code for every single 
    thing unlike other programming languages

    
5. Interpreted:
    When a programming language is interpreted, it means that the source code is 
    executed line by line, and not all at once
    
    Programming languages such as C++ or Java are not interpreted, and 
    hence need to be compiled first to run them.
    
    There is no need to compile Python because it is processed at runtime by the interpreter. 

    debugging easy and portable
    
6. Dynamically Typed:
    no need to declare the type of the variable
    
7. High-level Language:
    Python is a high-level programming language because programmers don’t need to remember 
    the system architecture, nor do they have to manage the memory. This makes it super 
    programmer-friendly and is one of the key features of Python.

8. Procedure oriented and object oriented language:
    Pyhton supports both object oriented (Java, C++) and Procedure oriented (like C) 
    so we can have both benifits like reusability and security

# %%
a = 10

if a>=5 :
    print("a is greater than 5")
else:
    print("a is less than 5")
# Out:
# a is greater than 5
